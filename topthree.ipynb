# %%
hot_dog_places <-read.csv("hot-dog-places.csv",
sep=",", header=TRUE)
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on 'hot-dog-places.csv'”

# %%
names(hot_dog_places)<-c("2000", "2001", "2002", "2003", "2004",
                         "2005", "2006", "2007", "2008", "2009", "2010")
hot_dog_matrix <- as.matrix(hot_dog_places)
barplot(hot_dog_matrix, border=NA, space=0.25, ylim=c(0, 200),xlim=c(0,12.5),col=c("#146c36","#4f9e53","#93b958"),
xlab="Year", ylab="Hot dogs and buns (HDBs) eaten",
main="Hot Dog Eating Contest Results, 1980-2010")
# Out:
# Plot with title “Hot Dog Eating Contest Results, 1980-2010”
